# %% [markdown]
# <img align="left" src="https://quantumspain-project.es/wp-content/uploads/2022/11/Logo_QS_EspanaDigital.png" width="1000px"/><br><br><br><br>
#
#
# # QML (Quantum Machine Learning)
#
# Created: 2022/10/30
#
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img aling="left" alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />License: <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Licencia Creative Commons Atribución-CompartirIgual 4.0 Internacional</a>.
# Internal Reviewers:
# * Alba Cervera ([BSC](https://www.bsc.es/))
#
# Authors:
# * Carmen Calvo ([SCAYLE](https://www.scayle.es/))
# * Antoni Alou ([PIC](https://www.pic.es/))
# * Carlos Hernani ([UV](https://www.uv.es/))
# * Nahia Iriarte ([NASERTIC](https://www.nasertic.es/es))
# * Carlos Luque ([IAC](https://www.iac.es/))

# %% [markdown]
# # Índice de contenidos
#
#
# ### [1. Introducción](Chapter_01_Introduction.ipynb)
# >- [**1.1 $~$ Machine Learning**](Chapter_01_Introduction.ipynb#sec_ML)<br>
# >- [**1.2 $~$ Quantum Machine Learning**](Chapter_01_Introduction.ipynb#sec_QML)<br>
# >- [**1.3 $~$ Conceptos**](Chapter_01_Introduction.ipynb#sec_ConceptosIntro)<br>
# >- [**Referencias**](Chapter_01_Introduction.ipynb#sec_referencias)<br>
# <br>
#
# ### [2. Feature Encoding](Chapter_02_Feature_encoding.ipynb)
# >- [**2.1 $~$ Basis encoding**](Chapter_02_Feature_encoding.ipynb#sec_BasisEncoding)<br>
# >- [**2.2 $~$ Amplitude encoding**](Chapter_02_Feature_encoding.ipynb#sec_AmplitudeEncoding)
# >- [**2.3 $~$ Angle encoding**](Chapter_02_Feature_encoding.ipynb#sec_angleEncoding)
# >- [**2.4 $~$ Dense Angle encoding**](Chapter_02_Feature_encoding.ipynb#sec_DenseAngleEncoding)
# >- [**2.5 $~$ Cómo escoger feature encoding**](Chapter_02_Feature_encoding.ipynb#sec_EleccionFeatureEncoding)
# >- [**Referencias**](Chapter_02_Feature_encoding.ipynb#sec_referencias)<br>
# <br>
#
# ### [3. Variational Quantum Classifier (VQC)](Chapter_03_VQC.ipynb)
# >- [**3.1 $~$ Variational Quantum Circuit**](Chapter_03_VQC.ipynb#sec_VariationalQuantumCirc)<br>
# >- [**3.2 $~$ Ejemplo de aplicación**](Chapter_03_VQC.ipynb#sec_Ejemplo)<br>
# >- [**Referencias**](Chapter_03_VQC.ipynb#sec_referencias)<br>
# <br>
#
# ### [4. Quantum Support Vector Machines (QSVM)](Chapter_04_QSVM.ipynb)
# >- [**4.1 $~$ Support Vector Machines (SVM)**](Chapter_04_QSVM.ipynb#sec_SVM)<br>
# >- [**4.2 $~$ Clasificador de vectores soporte cuántico (QSVC)**](Chapter_04_QSVM.ipynb#sec_QSVC)
# >>- [4.2.1 Ejemplo de QSVM en Qibo](Chapter_04_QSVM.ipynb#sec_EjemploQSVC)
# >- [**Referencias**](Chapter_04_QSVM.ipynb#sec_referencias)<br>
# <br>
#
# ### [5. Quantum Kernels](Chapter_05_Kernel.ipynb)
# >- [**5.1 $~$ Introducción a los métodos kernel**](Chapter_05_Kernel.ipynb#sec_IntroKernel)<br>
# >- [**5.2 $~$ Introducción al kernel cuántico**](Chapter_05_Kernel.ipynb#sec_IntroQuantumKernel)
# >- [**5.3 $~$ Distintas implementaciones de kernel**](Chapter_05_Kernel.ipynb#sec_ImplementacionesKernel)
# >>- [5.3.1 SWAP test](Chapter_05_Kernel.ipynb#sec_SWAPtest)<br>
# >>- [5.3.2 Quantum Kernel Estimator (QKE)](Chapter_05_Kernel.ipynb#sec_QKE)
# >>>- [5.3.2.1 Quantum Kernel Estimator - proyector](Chapter_05_Kernel.ipynb#sec_QKE_proyector)<br>
# >>>- [5.3.2.2 Quantum Kernel Estimator - probabilidades](Chapter_05_Kernel.ipynb#sec_QKE_proba) <br>
# >- [**Referencias**](5_Kernel.ipynb#sec_references)<br>
# <br>
#
# ### [6. Optimizadores](Chapter_06_Optimizadores.ipynb)
# >- [**6.1 $~$ Descenso por gradiente**](Chapter_06_Optimizadores.ipynb#sec_DescensoGradiente)<br>
# >>- [6.1.1 Problemas del descenso por gradiente](Chapter_06_Optimizadores.ipynb#sec_DGproblemas)<br>
# >>- [6.1.2 Implementación](Chapter_06_Optimizadores.ipynb#sec_DGimplementacion)<br>
# >- [**6.2 $~$ Momentum**](Chapter_06_Optimizadores.ipynb#sec_momentum)
# >>- [6.2.1 Algoritmo](Chapter_06_Optimizadores.ipynb#sec_momentumAlgoritmo)<br>
# >>- [6.2.2 Cómo seleccionar $\beta$](Chapter_06_Optimizadores.ipynb#sec_momentumBeta)<br>
# >>- [6.2.3 Implementación](Chapter_06_Optimizadores.ipynb#sec_momentumImplementacion)<br>
# >- [**6.3 $~$ Nesterov Momentum Optimizer**](Chapter_06_Optimizadores.ipynb#sec_Nesterov)
# >>- [6.3.1 Algoritmo](Chapter_06_Optimizadores.ipynb#sec_NesterovAlgortimo)<br>
# >>- [6.3.2 Implementación](Chapter_06_Optimizadores.ipynb#sec_NesterovImplementacion)<br>
# >- [**6.4 $~$ Adam**](Chapter_06_Optimizadores.ipynb#sec_Adam)
# >>- [6.4.1 Algoritmo](Chapter_06_Optimizadores.ipynb#sec_AdamAlgoritmo)<br>
# >>- [6.4.2 Implementación](Chapter_06_Optimizadores.ipynb#sec_AdamImplementacion)<br>
# >- [**6.5 $~$ Adadelta**](Chapter_06_Optimizadores.ipynb#sec_Adadelta)
# >>- [6.5.1 Algoritmo](Chapter_06_Optimizadores.ipynb#sec_AdadeltaAlgoritmo)<br>
# >>- [6.5.2 Implementación](Chapter_06_Optimizadores.ipynb#sec_AdadeltaImplementacion)<br>
# >- [**6.6 $~$ Powell**](Chapter_06_Optimizadores.ipynb#sec_Powell)
# >- [**6.7 $~$ BFGS**](Chapter_06_Optimizadores.ipynb#sec_BFGS)
#
#
# >- [**Referencias**](Chapter_06_Optimizadores.ipynb#sec_references)<br>
# <br>

# %% [markdown]
# This work has been financially supported by the Ministry of Economic Affairs and Digital Transformation of the Spanish Government through the QUANTUM ENIA project call - Quantum Spain project, and by the European Union through the Recovery, Transformation and Resilience Plan - NextGenerationEU within the framework of the Digital Spain 2025 Agenda.
#
#
# <img align="left" src="https://quantumspain-project.es/wp-content/uploads/2022/11/LOGOS-GOB_QS.png" width="1000px" />
